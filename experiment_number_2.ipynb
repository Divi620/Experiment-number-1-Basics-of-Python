# %% [markdown]
# <a href="https://colab.research.google.com/github/Divi620/Experiment-number-1-Basics-of-Python/blob/main/experiment_number_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unit 1
# # Experiment no. 1: basics of Python
# ##Name: Divisha Ingavale
# ## PRN: 250701043
# ## Branch: ENTC
# ## Batch: A2
# ## Date: 13th January 2026

# %%
#First python program/string
print("Hello, welcome to python Programming")
# Out:
# Hello, welcome to python Programming

# %%
a = 'Hello'
print(a)
# Out:
# Hello

# %%
#Comments
#This is a comment
print("Hello, World!")
# Out:
# Hello, World!

# %%
#Many statements
print("Hello, World!")
print("Have a good day")
print("Learning python is fun!")
# Out:
# Hello, World!
# Have a good day
# Learning python is fun!

# %%
#Three logical statements as output with a single input line using semicolon (;)
print("Hello");print("How are you");print("Bye bye!")
# Out:
# Hello
# How are you
# Bye bye!

# %%
# Print numbers
a = 3
print(a)
print(358)
print(500,200)
# Out:
# 3
# 358
# 500 200

# %%
#Variables
x=5
y="Hello, World!"

print(x)
print(y)
# Out:
# 5
# Hello, World!

# %%
#Case Sensitive
a=4
A="Sally"

print(a)
print(A)
# Out:
# 4
# Sally

# %%
#Many values to Multiple variables
x,y,z = "Orange","Banana","Cherry"

print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
#Basic Arithmetic Operations
a =10
b=5
print("Addition =",a+b)
print("Division =",a/b)
# Out:
# Addition = 15
# Division = 2.0

# %%
#Understanding data types
x=10
y=3.14
z="Python"
A=True
C=3+2j

print(type(x))
print(type(y))
print(type(z))
print(type(A))
print(type(C))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
#Taking input from user
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Name", name)
print("Age", age)
# Out:
# Enter your name: Divisha
# Enter your age: 19
# Name Divisha
# Age 19

# %%
#Simple calculator
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print(a+b)
print(a-b)
print(a/b)
print(a*b)
# Out:
# Enter first number: 3
# Enter second number: 5
# 8
# -2
# 0.6
# 15

# %%
#Take marks of 5 subjects and find the sum and average

a=float(input("Marks for Maths: "))
b=float(input("Marks for Physics: "))
c=float(input("Marks for Chemistry: "))
d=float(input("Marks for Biology: "))
e=float(input("Marks for Economics: "))

f = a+b+c+d+e
print(f)
print(f/5)
# Out:
# Marks for Maths: 34
# Marks for Physics: 54
# Marks for Chemistry: 67
# Marks for Biology: 79
# Marks for Economics: 89
# 323.0
# 64.6

# %%
#Find area of circle

a=float(input("Value of r: "))
print(a*a*3.14)
# Out:
# Value of r: 4
# 50.24

# %%
#Find area of rectangle
l=float(input("Value of l: "))
b=float(input("Value of b: "))
print(l*b)
# Out:
# Value of l: 3
# Value of b: 6
# 18.0

# %%
#Find perimeter of rectangle
l=float(input("Value of l: "))
b=float(input("Value of b: "))

print((2*l) +(2*b))
# Out:
# Value of l: 5
# Value of b: 7
# 24.0

# %%
# Python Booleans
print(10>9)
print(10==9)
print(10<9)
# Out:
# True
# False
# False
